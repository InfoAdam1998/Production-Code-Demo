# %% [markdown]
# # 1. Data collection

# %%
import pandas as pd

# %%
data = pd.read_csv("Dataset/rent_apartments.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv("rent_apartments.csv")
#
# File c:\Users\steve\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\steve\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\steve\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\steve\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\steve\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rent_apartments.csv'

# %%
data
# Out:
#                                        address   area  constraction_year  \
# 0     1071 HN Amsterdam (Cornelis Schuytbuurt)  167.0               1870
# 1       1071 HK Amsterdam (Concertgebouwbuurt)  150.0               1890
# 2       1071 HK Amsterdam (Concertgebouwbuurt)  150.0               1890
# 3         1071 WV Amsterdam (Hondecoeterbuurt)   90.0               1923
# 4         1071 WV Amsterdam (Hondecoeterbuurt)  104.0               1923
# ...                                        ...    ...                ...
# 1723            1033 DL Amsterdam (Terrasdorp)   75.0               1990
# 1724            1033 DZ Amsterdam (Terrasdorp)   75.0               1990
# 1725          1021 NX Amsterdam (IJplein e.o.)   74.0               1986
# 1726       1021 EC Amsterdam (Vogelbuurt Zuid)  118.0               1920
# 1727       1042 AL Amsterdam (Westhaven Noord)  110.0               2019
#
#       rooms  bedrooms  bathrooms balcony storage parking furnished garage  \
# 0         3         2          2     yes      no      no       yes     no
# 1         3         2          2     yes      no     yes       yes     no
# 2         3         2          2     yes      no     yes       yes     no
# 3         3         2          1     yes      no      no       yes     no
# 4         3         2          1      no      no      no        no     no
# ...     ...       ...        ...     ...     ...     ...       ...    ...
# 1723      3         2          1      no      no      no       yes     no
# 1724      3         2          1     yes      no      no       yes     no
# 1725      2         1          1      no      no      no       yes     no
# 1726      5         4          1     yes     yes     yes       yes     no
# 1727      5         4          2      no     yes      no       yes     no
#
#                garden energy  \
# 0         Not present      D
# 1         Not present      A
# 2         Not present      A
# 3         Not present    NaN
# 4     Present (47 m²)      D
# ...               ...    ...
# 1723      Not present      C
# 1724      Not present      C
# 1725      Not present    NaN
# 1726      Not present      G
# 1727      Not present    NaN
#
#                                              facilities      zip  \
# 0                                          Roof terrace  1071 HN
# 1     Cable TV, Internet connection, Fireplace, Bath...  1071 HK
# 2     Cable TV, Internet connection, Fireplace, Bath...  1071 HK
# 3                                        Shower, Toilet  1071 WV
# 4                                  Shower, Bath, Toilet  1071 WV
# ...                                                 ...      ...
# 1723                                                NaN  1033 DL
# 1724                                             Shower  1033 DZ
# 1725                                                NaN  1021 NX
# 1726                      Storage space, Shower, Toilet  1021 EC
# 1727  Internet connection, Air-conditioning, Storage...  1042 AL
#
#               neighborhood  rent
# 0     Cornelis Schuytbuurt  4500
# 1       Concertgebouwbuurt  3450
# 2       Concertgebouwbuurt  3450
# 3         Hondecoeterbuurt  2000
# 4         Hondecoeterbuurt  3250
# ...                    ...   ...
# 1723            Terrasdorp  1450
# 1724            Terrasdorp  1500
# 1725          IJplein e.o.  1400
# 1726       Vogelbuurt Zuid  2650
# 1727       Westhaven Noord  2600
#
# [1728 rows x 17 columns]

# %% [markdown]
# # 2. Data preparation

# %%
data.dtypes
# Out:
# address               object
# area                 float64
# constraction_year      int64
# rooms                  int64
# bedrooms               int64
# bathrooms              int64
# balcony               object
# storage               object
# parking               object
# furnished             object
# garage                object
# garden                object
# energy                object
# facilities            object
# zip                   object
# neighborhood          object
# rent                   int64
# dtype: object

# %%
data_encoded = pd.get_dummies(data, 
                              columns = ['balcony',
                                         'parking', 
                                         'furnished', 
                                         'garage', 
                                         'storage'], 
                              drop_first=True)

# %%
data_encoded
# Out:
#                                        address   area  constraction_year  \
# 0     1071 HN Amsterdam (Cornelis Schuytbuurt)  167.0               1870
# 1       1071 HK Amsterdam (Concertgebouwbuurt)  150.0               1890
# 2       1071 HK Amsterdam (Concertgebouwbuurt)  150.0               1890
# 3         1071 WV Amsterdam (Hondecoeterbuurt)   90.0               1923
# 4         1071 WV Amsterdam (Hondecoeterbuurt)  104.0               1923
# ...                                        ...    ...                ...
# 1723            1033 DL Amsterdam (Terrasdorp)   75.0               1990
# 1724            1033 DZ Amsterdam (Terrasdorp)   75.0               1990
# 1725          1021 NX Amsterdam (IJplein e.o.)   74.0               1986
# 1726       1021 EC Amsterdam (Vogelbuurt Zuid)  118.0               1920
# 1727       1042 AL Amsterdam (Westhaven Noord)  110.0               2019
#
#       rooms  bedrooms  bathrooms           garden energy  \
# 0         3         2          2      Not present      D
# 1         3         2          2      Not present      A
# 2         3         2          2      Not present      A
# 3         3         2          1      Not present    NaN
# 4         3         2          1  Present (47 m²)      D
# ...     ...       ...        ...              ...    ...
# 1723      3         2          1      Not present      C
# 1724      3         2          1      Not present      C
# 1725      2         1          1      Not present    NaN
# 1726      5         4          1      Not present      G
# 1727      5         4          2      Not present    NaN
#
#                                              facilities      zip  \
# 0                                          Roof terrace  1071 HN
# 1     Cable TV, Internet connection, Fireplace, Bath...  1071 HK
# 2     Cable TV, Internet connection, Fireplace, Bath...  1071 HK
# 3                                        Shower, Toilet  1071 WV
# 4                                  Shower, Bath, Toilet  1071 WV
# ...                                                 ...      ...
# 1723                                                NaN  1033 DL
# 1724                                             Shower  1033 DZ
# 1725                                                NaN  1021 NX
# 1726                      Storage space, Shower, Toilet  1021 EC
# 1727  Internet connection, Air-conditioning, Storage...  1042 AL
#
#               neighborhood  rent  balcony_yes  parking_yes  furnished_yes  \
# 0     Cornelis Schuytbuurt  4500         True        False           True
# 1       Concertgebouwbuurt  3450         True         True           True
# 2       Concertgebouwbuurt  3450         True         True           True
# 3         Hondecoeterbuurt  2000         True        False           True
# 4         Hondecoeterbuurt  3250        False        False          False
# ...                    ...   ...          ...          ...            ...
# 1723            Terrasdorp  1450        False        False           True
# 1724            Terrasdorp  1500         True        False           True
# 1725          IJplein e.o.  1400        False        False           True
# 1726       Vogelbuurt Zuid  2650         True         True           True
# 1727       Westhaven Noord  2600        False        False           True
#
#       garage_yes  storage_yes
# 0          False        False
# 1          False        False
# 2          False        False
# 3          False        False
# 4          False        False
# ...          ...          ...
# 1723       False        False
# 1724       False        False
# 1725       False        False
# 1726       False         True
# 1727       False         True
#
# [1728 rows x 17 columns]

# %%
data_encoded.garden.unique()
# Out:
# array(['Not present', 'Present (47 m²)', 'Present (29 m²)',
#        'Present (75 m²)', 'Present (40 m², located on the north)',
#        'Present (50 m²)', 'Present (20 m², located on the south)',
#        'Present (1 m²)', 'Present (15 m²)', 'Present (25 m²)',
#        'Present (12 m²)', 'Present (45 m², located on the south)',
#        'Present (26 m², located on the south-east)',
#        'Present (20 m², located on the north-east)',
#        'Present (42 m², located on the west)', 'Present (46 m²)',
#        'Present (45 m², located on the south-west)',
#        'Present (60 m², located on the south-west)',
#        'Present (50 m², located on the south)',
#        'Present (40 m², located on the north-east)', 'Present (16 m²)',
#        'Present (60 m²)', 'Present (65 m², located on the south)',
#        'Present (90 m²)', 'Present (85 m²)',
#        'Present (85 m², located on the south-west)',
#        'Present (500 m², located on the west)',
#        'Present (45 m², located on the west)',
#        'Present (12 m², located on the south)',
#        'Present (30 m², located on the north-west)',
#        'Present (60 m², located on the south-east)',
#        'Present (49 m², located on the east)',
#        'Present (51 m², located on the south-east)', 'Present (80 m²)',
#        'Present (27 m²)', 'Present (56 m²)', 'Present (65 m²)',
#        'Present (20 m²)', 'Present (9 m²)', 'Present (200 m²)',
#        'Present (32 m²)', 'Present (45 m²)',
#        'Present (100 m², located on the south)', 'Present (34 m²)'],
#       dtype=object)

# %%
import re

# %%
data_encoded.garden[3]
# Out:
# 'Not present'

# %%
int(re.findall(r'\d+', data_encoded.garden[3])[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 int(re.findall(r'\d+', data_encoded.garden[3])[0])
#
# IndexError: list index out of range

# %%
for i in range(len(data_encoded)):
    if data_encoded.garden[i]=='Not present':
        data_encoded.garden[i]=0
    else: data_encoded.garden[i] = int(re.findall(r'\d+', data_encoded.garden[i])[0])
# Out:
# /var/folders/5y/7zvhsc3x5nx162713kvx9c1m0000gn/T/ipykernel_46869/3850921411.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_encoded.garden[i]=0
# /var/folders/5y/7zvhsc3x5nx162713kvx9c1m0000gn/T/ipykernel_46869/3850921411.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: data_encoded.garden[i] = int(re.findall(r'\d+', data_encoded.garden[i])[0])

# %%
data_encoded.garden.unique()
# Out:
# array([0, 47, 29, 75, 40, 50, 20, 1, 15, 25, 12, 45, 26, 42, 46, 60, 16,
#        65, 90, 85, 500, 30, 49, 51, 80, 27, 56, 9, 200, 32, 100, 34],
#       dtype=object)

# %% [markdown]
# # 3. Model Building

# %% [markdown]
# ## 3.1. Defining X and y

# %%
X = data_encoded[['area', 
                  'constraction_year', 
                  'bedrooms', 
                  'garden', 
                  'balcony_yes', 
                  'parking_yes', 
                  'furnished_yes', 
                  'garage_yes', 
                  'storage_yes']]

# %%
y = data_encoded.rent

# %%
y
# Out:
# 0       4500
# 1       3450
# 2       3450
# 3       2000
# 4       3250
#         ...
# 1723    1450
# 1724    1500
# 1725    1400
# 1726    2650
# 1727    2600
# Name: rent, Length: 1728, dtype: int64

# %%
X
# Out:
#        area  constraction_year  bedrooms garden  balcony_yes  parking_yes  \
# 0     167.0               1870         2      0            1            0
# 1     150.0               1890         2      0            1            1
# 2     150.0               1890         2      0            1            1
# 3      90.0               1923         2      0            1            0
# 4     104.0               1923         2     47            0            0
# ...     ...                ...       ...    ...          ...          ...
# 1723   75.0               1990         2      0            0            0
# 1724   75.0               1990         2      0            1            0
# 1725   74.0               1986         1      0            0            0
# 1726  118.0               1920         4      0            1            1
# 1727  110.0               2019         4      0            0            0
#
#       furnished_yes  garage_yes  storage_yes
# 0                 1           0            0
# 1                 1           0            0
# 2                 1           0            0
# 3                 1           0            0
# 4                 0           0            0
# ...             ...         ...          ...
# 1723              1           0            0
# 1724              1           0            0
# 1725              1           0            0
# 1726              1           0            1
# 1727              1           0            1
#
# [1728 rows x 9 columns]

# %% [markdown]
# ## 3.2. Split the dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## 3.3. Model Building

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## 3.4. Evaluate Model

# %%
rf.score(X_test, y_test)
# Out:
# 0.5430670976676156

# %% [markdown]
# ## 3.5. Predicting

# %%
X
# Out:
#        area  constraction_year  bedrooms garden  balcony_yes  parking_yes  \
# 0     167.0               1870         2      0            1            0
# 1     150.0               1890         2      0            1            1
# 2     150.0               1890         2      0            1            1
# 3      90.0               1923         2      0            1            0
# 4     104.0               1923         2     47            0            0
# ...     ...                ...       ...    ...          ...          ...
# 1723   75.0               1990         2      0            0            0
# 1724   75.0               1990         2      0            1            0
# 1725   74.0               1986         1      0            0            0
# 1726  118.0               1920         4      0            1            1
# 1727  110.0               2019         4      0            0            0
#
#       furnished_yes  garage_yes  storage_yes
# 0                 1           0            0
# 1                 1           0            0
# 2                 1           0            0
# 3                 1           0            0
# 4                 0           0            0
# ...             ...         ...          ...
# 1723              1           0            0
# 1724              1           0            0
# 1725              1           0            0
# 1726              1           0            1
# 1727              1           0            1
#
# [1728 rows x 9 columns]

# %%
rf.predict([[85, 2015, 2, 20, 1, 1, 0, 0, 1]])
# Out:
# /Users/andrewwolf/.pyenv/versions/3.10.7/lib/python3.10/site-packages/sklearn/base.py:409: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([1903.60033333])

# %% [markdown]
# ## 3.6. Tuning Hyperparameters

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_space = {'n_estimators': [100, 200, 300], 'max_depth': [3, 6, 9, 12]}

# %%
grid = GridSearchCV(RandomForestRegressor(), param_grid=grid_space, cv=5, scoring = 'r2')

# %%
model_grid = grid.fit(X_train, y_train)

# %%
print(f'Best hyperparameters are {model_grid.best_params_}, score = {model_grid.best_score_}')
# Out:
# Best hyperparameters are {'max_depth': 12, 'n_estimators': 100}, score = 0.732347841612605

# %%
model_grid.best_estimator_.predict([[85, 2015, 2, 20, 1, 1, 0, 0, 1]])
# Out:
# /Users/andrewwolf/.pyenv/versions/3.10.7/lib/python3.10/site-packages/sklearn/base.py:409: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([1939.50041667])

# %% [markdown]
# # 4. Models Management

# %%
import pickle as pk

# %%
pk.dump(rf, open('models/rf_v1', 'wb'))

# %%
# !ls models/
# Out:
# rf_v1

# %%
rf_v1 = pk.load(open('models/rf_v1', 'rb'))

# %%
rf_v1.predict([[85, 2015, 2, 20, 1, 1, 0, 0, 1]])
# Out:
# /Users/andrewwolf/.pyenv/versions/3.10.7/lib/python3.10/site-packages/sklearn/base.py:409: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([1984.13478277])
